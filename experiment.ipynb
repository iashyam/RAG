# %%
import json

# %%
movies_json = json.load("data/movies.json")
# Out:
# Running cells with 'rag-search-engine (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/taylor/github/rag-search-engine/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
